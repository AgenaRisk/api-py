# %%
from pyagena import *

# %% [markdown]
# Installing the local agena.ai developer API. Nothing needs to be installed beforehand: the API, a Java runtime and the licensing components are downloaded into `~/.agena.ai/tools`, shared with agena.ai Explorer and any other local client.
#
# This is safe to leave at the top of a script — it installs only what is missing, and never upgrades you unasked.

# %%
local_api_install()
# Out:
# The local api environment is cloned to the working directory successfully

# %%
local_api_install(update=True) #to check for and install a newer version
# Out:
# The local api environment is compiled with maven successfully

# %%
local_api_install(channel="snapshot") #to install an unreleased build instead

# %%
local_api_activate_license("1234-ABCD-5678-EFGH") #if needed to activate a new license

# %%
local_api_show_license() #to get license information

# %%
local_api_deactivate_license() #if needed to deactivate the current license
